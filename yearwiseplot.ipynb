# %%
from yearlyplotforsubsets import yearlyplot
import yearlyplotforsubsets
from regimesgroupplot import groupregimesplot
import pandas as pd
import regimes
import glob

# %%
DE_Hai=pd.read_csv(r'../datasets/Subsets_Forest/FLX_DE-Hai_FLUXNET2015_SUBSET_DD_2000-2012_1-4.csv')

# %%
#yearlyplotforsubsets.yearlyplot(AU_Cpr,3,70,'AU_Cpr')

# %%
#yearlyplotforsubsets.yearlyplot(AU_Gin,3,50,'AU_Gin')

# %%
#yearlyplotforsubsets.yearlyplot(CA_NS2,3,80,'CA_NS2')

# %%
#yearlyplotforsubsets.yearlyplot(CA_TP4,2,100,'CA_TP4')

# %%
#yearlyplotforsubsets.yearlyplot(CN_Cng,3,60,'CN_Cng')

# %%
#plt.legend(handles=legend_handles)yearlyplotforsubsets.yearlyplot(CN_Qia,3,50,'CN_Qia')

# %%
#yearlyplotforsubsets.yearlyplot(DE_Geb,2,100,'DE_Geb')

# %%
yearlyplotforsubsets.yearlyplot(DE_Hai,3,50,'DE_Hainich',startyear=2006,endyear=2011)

# %%
#yearlyplotforsubsets.yearlyplot(DE_Kli,2,80,'DE_Kli')

# %%
#yearlyplotforsubsets.yearlyplot(DE_Spw,3,50,'DE_Spw')

# %%
#yearlyplotforsubsets.yearlyplot(FI_Lom,3,180,'FI_Lom')

# %%
#yearlyplotforsubsets.yearlyplot(IT_Col,2,70,'IT_Col')

# %%
#yearlyplotforsubsets.yearlyplot(RU_Fyo,3,80,'RU_Fyo')

# %%
#yearlyplotforsubsets.yearlyplot(US_Blo,3,50,'US_Blo')

# %%
#yearlyplotforsubsets.yearlyplot(US_Goo,3,40,'US_Goo')

# %%
#yearlyplotforsubsets.yearlyplot(US_Src,2,40,'US_Src')
